# %%
import DSGRN
from pychomp import *

# %%
def dsgrn(pg, pi, method = "blowup"):
    p = pg.parameter(pi)
    if method == "original":
        dg = DSGRN.DomainGraph(p)
        md = DSGRN.MorseDecomposition(dg.digraph())
        mg = DSGRN.MorseGraph(dg, md)
        return DSGRN.DrawGraph(mg)  
    if method == "cubical":
        std = DSGRN.SubdomainGraph(p)
    elif method == "blowup":
        std = DSGRN.BlowupGraph(p)
    (dag, fibration)= ConleyMorseFibration(std.complex(), std.diagram())
    connection_matrix = ConnectionMatrix(fibration)
    conleyindices = connection_matrix.count()
    fringenode = fibration.value(std.complex().size()-1)
    del conleyindices[fringenode]
    CMG = InducedPoset(dag, lambda v : v in conleyindices)
    return DrawFibration(connection_matrix, CMG)

# %%
def ComputeDatabase(netspec, params = None):
    network = DSGRN.Network(netspec)
    pg = DSGRN.ParameterGraph(network)
    if not params:
        params = range(0,pg.size())
    return DSGRN.Table( ['ParameterIndex','Original', 'Cubical', 'Blowup'], 
                   [[pi,
                     dsgrn(pg, pi, "original"), 
                     dsgrn(pg, pi, "cubical"), 
                     dsgrn(pg, pi, "blowup")] for pi in params])

# %%
ComputeDatabase("X : ~Y\n Y : ~X\n")
# Out:
# <div style="border:1px black"><table><tr><th><div style="text-align:center;">ParameterIndex</div></th><th><div style="text-align:center;">Original</div></th><th><div style="text-align:center;">Cubical</div></th><th><div style="text-align:center;">Blowup</div></th></tr><tr><td><div style="text-align:center;">0</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 0, 0 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">1</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 1, 0 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">2</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 1, 0 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by gra

# %%
ComputeDatabase('X :  X ~Y\n Y : ~X Y \n', params = range(100,200))
# Out:
# <div style="border:1px black"><table><tr><th><div style="text-align:center;">ParameterIndex</div></th><th><div style="text-align:center;">Original</div></th><th><div style="text-align:center;">Cubical</div></th><th><div style="text-align:center;">Blowup</div></th></tr><tr><td><div style="text-align:center;">100</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 0, 1 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">101</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 0, 1 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">102</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="218pt" height="44pt"
#  viewBox="0.00 0.00 218.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 214.0135,-40 214.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 0, 1 }</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="162.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="162.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 1, 1 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="224pt" height="116pt"
#  viewBox="0.00 0.00 223.81 116.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-112 219.8117,-112 219.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size=
